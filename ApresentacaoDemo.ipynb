# %% [markdown]
# # Apresentação Heroes.csv
#
# ## Aluno: Asdrubal Dino
#
# **Blah**

# %%
# !pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 10.3 MB 8.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 18.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 11.6 MB/s eta 0:00:01
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy  as np

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2018', periods=1000))
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()

# %% [markdown]
# ## Análise das vendas dos 4 produtos

# %%
plt.figure(); df.plot();

# %% [markdown]
# # Este é um titulo

# %% [markdown]
# Essa é uma lista de itens
# - item 1
# - item 2
# - item 3
